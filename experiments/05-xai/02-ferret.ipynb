# %%
# %run ../ipynb_util_tars.py

# %% [markdown]
# # ferret on finetuned SciBERT

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# SciBERT
SCIBERT_PATH = CHECKPOINT_PATH + "/final/allenai/scibert_scivocab_cased-zo_up/checkpoint-432/"

scibert_model = AutoModelForSequenceClassification.from_pretrained(
    SCIBERT_PATH
)
scibert_tokenizer = AutoTokenizer.from_pretrained(SCIBERT_PATH)

# %%
from ferret import Benchmark

sentence = "Buying support at international negotiations: the strategic use of climate aid The relationship between aid and voting in UN agencies has been well documented in the aid literature. We extend this analysis to the wider field of international negotiations, outside the sphere of formal voting, where decisions are mostly taken by consensus. Is aid used strategically to influence the negotiations in this context, too? Based on a novel dataset on negotiation behavior under the UN Framework Convention on Climate Change we assess whether countries obtaining aid react by expressing increased support and/or reduced opposition towards the donor. Applying linear and instrumental variable regressions on a three-dimensional panel dataset with donor-recipient dyads for the period 2002-2013 enables us to distinguish between long-term partnerships and the strategic use of aid for the purpose of the negotiations. We find that aid can indeed buy support in the climate negotiations, but that this opportunity tends to be limited to mitigation and adaptation aid, rather than general aid. We argue that this is due to both greater demand for and greater supply of these specific types of aid, whose allocation is under the direct responsibility of the specialized delegates participating in the negotiations."
sentence = "Is this about clean energy?"
bench = Benchmark(scibert_model, scibert_tokenizer)
explanations = bench.explain(sentence, target=13)
bench.show_table(explanations)
# Out:
# Explainer:   0%|          | 0/6 [00:00<?, ?it/s]
# <style type="text/css">
# #T_18649_row0_col0 {
#   background-color: #f2efef;
#   color: #000000;
# }
# #T_18649_row0_col1 {
#   background-color: #f0e0e1;
#   color: #000000;
# }
# #T_18649_row0_col2, #T_18649_row1_col1 {
#   background-color: #eceef1;
#   color: #000000;
# }
# #T_18649_row0_col3 {
#   background-color: #a1bcd0;
#   color: #000000;
# }
# #T_18649_row0_col4 {
#   background-color: #adc4d6;
#   color: #000000;
# }
# #T_18649_row0_col5, #T_18649_row4_col5 {
#   background-color: #edeff1;
#   color: #000000;
# }
# #T_18649_row1_col0 {
#   background-color: #f2f1f1;
#   color: #000000;
# }
# #T_18649_row1_col2 {
#   background-color: #cbd8e3;
#   color: #000000;
# }
# #T_18649_row1_col3 {
#   background-color: #a8c1d3;
#   color: #000000;
# }
# #T_18649_row1_col4 {
#   background-color: #b8ccda;
#   color: #000000;
# }
# #T_18649_row1_col5 {
#   background-color: #f2eeee;
#   color: #000000;
# }
# #T_18649_row2_col0, #T_18649_row4_col2 {
#   background-color: #f1e8e9;
#   color: #000000;
# }
# #T_18649_row2_col1 {
#   background-color: #f1e7e7;
#   color: #000000;
# }
# #T_18649_row2_col2 {
#   background-color: #f0e3e3;
#   color: #000000;
# }
# #T_18649_row2_col3 {
#   background-color: #ebbbbe;
#   color: #000000;
# }
# #T_18649_row2_col4 {
#   background-color: #ecc5c7;
#   color: #000000;
# }
# #T_18649_row2_col5 {
#   background-color: #f1e4e5;
#   color: #000000;
# }
# #T_18649_row3_col0 {
#   background-color: #e7ebee;
#   color: #000000;
# }
# #T_18649_row3_col1, #T_18649_row5_col0 {
#   background-color: #d8e1e8;
#   color: #000000;
# }
# #T_18649_row3_col2, #T_18649_row3_col5, #T_18649_row5_col1 {
#   background-color: #eecfd1;
#   color: #000000;
# }
# #T_18649_row3_col3 {
#   background-color: #dde4ea;
#   color: #000000;
# }
# #T_18649_row3_col4 {
#   background-color: #eed1d3;
#   color: #000000;
# }
# #T_18649_row4_col0 {
#   background-color: #efd6d7;
#   color: #000000;
# }
# #T_18649_row4_col1 {
#   background-color: #d1dce5;
#   color: #000000;
# }
# #T_18649_row4_col3 {
#   background-color: #dce3ea;
#   color: #000000;
# }
# #T_18649_row4_col4 {
#   background-color: #e8a5aa;
#   color: #000000;
# }
# #T_18649_row5_col2 {
#   background-color: #e9edf0;
#   color: #000000;
# }
# #T_18649_row5_col3 {
#   background-color: #a5bfd2;
#   color: #000000;
# }
# #T_18649_row5_col4 {
#   background-color: #f1f1f2;
#   color: #000000;
# }
# #T_18649_row5_col5 {
#   background-color: #cfdbe4;
#   color: #000000;
# }
# </style>
# <table id="T_18649">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Token</th>
#       <th id="T_18649_level0_col0" class="col_heading level0 col0" >is</th>
#       <th id="T_18649_level0_col1" class="col_heading level0 col1" >this</th>
#       <th id="T_18649_level0_col2" class="col_heading level0 col2" >about</th>
#       <th id="T_18649_level0_col3" class="col_heading level0 col3" >clean</th>
#       <th id="T_18649_level0_col4" class="col_heading level0 col4" >energy</th>
#       <th id="T_18649_level0_col5" class="col_heading level0 col5" >?</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18649_level0_row0" class="row_heading level0 row0" >Partition SHAP</th>
#       <td id="T_18649_row0_col0" class="data row0 col0" >0.01</td>
#       <td id="T_18649_row0_col1" class="data row0 col1" >0.09</td>
#       <td id="T_18649_row0_col2" class="data row0 col2" >-0.03</td>
#       <td id="T_18649_row0_col3" class="data row0 col3" >-0.46</td>
#       <td id="T_18649_row0_col4" class="data row0 col4" >-0.39</td>
#       <td id="T_18649_row0_col5" class="data row0 col5" >-0.02</td>
#     </tr>
#     <tr>
#       <th id="T_18649_level0_row1" class="row_heading level0 row1" >LIME</th>
#       <td id="T_18649_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_18649_row1_col1" class="data row1 col1" >-0.03</td>
#       <td id="T_18649_row1_col2" class="data row1 col2" >-0.22</td>
#       <td id="T_18649_row1_col3" class="data row1 col3" >-0.42</td>
#       <td id="T_18649_row1_col4" class="data row1 col4" >-0.32</td>
#       <td id="T_18649_row1_col5" class="data row1 col5" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_18649_level0_row2" class="row_heading level0 row2" >Gradient</th>
#       <td id="T_18649_row2_col0" class="data row2 col0" >0.05</td>
#       <td id="T_18649_row2_col1" class="data row2 col1" >0.06</td>
#       <td id="T_18649_row2_col2" class="data row2 col2" >0.08</td>
#       <td id="T_18649_row2_col3" class="data row2 col3" >0.30</td>
#       <td id="T_18649_row2_col4" class="data row2 col4" >0.25</td>
#       <td id="T_18649_row2_col5" class="data row2 col5" >0.07</td>
#     </tr>
#     <tr>
#       <th id="T_18649_level0_row3" class="row_heading level0 row3" >Gradient (x Input)</th>
#       <td id="T_18649_row3_col0" class="data row3 col0" >-0.06</td>
#       <td id="T_18649_row3_col1" class="data row3 col1" >-0.15</td>
#       <td id="T_18649_row3_col2" class="data row3 col2" >0.19</td>
#       <td id="T_18649_row3_col3" class="data row3 col3" >-0.11</td>
#       <td id="T_18649_row3_col4" class="data row3 col4" >0.17</td>
#       <td id="T_18649_row3_col5" class="data row3 col5" >0.19</td>
#     </tr>
#     <tr>
#       <th id="T_18649_level0_row4" class="row_heading level0 row4" >Integrated Gradient</th>
#       <td id="T_18649_row4_col0" class="data row4 col0" >0.16</td>
#       <td id="T_18649_row4_col1" class="data row4 col1" >-0.18</td>
#       <td id="T_18649_row4_col2" class="data row4 col2" >0.05</td>
#       <td id="T_18649_row4_col3" class="data row4 col3" >-0.12</td>
#       <td id="T_18649_row4_col4" class="data row4 col4" >0.42</td>
#       <td id="T_18649_row4_col5" class="data row4 col5" >-0.02</td>
#     </tr>
#     <tr>
#       <th id="T_18649_level0_row5" class="row_heading level0 row5" >Integrated Gradient (x Input)</th>
#       <td id="T_18649_row5_col0" class="data row5 col0" >-0.14</td>
#       <td id="T_18649_row5_col1" class="data row5 col1" >0.19</td>
#       <td id="T_18649_row5_col2" class="data row5 col2" >-0.04</td>
#       <td id="T_18649_row5_col3" class="data row5 col3" >-0.43</td>
#       <td id="T_18649_row5_col4" class="data row5 col4" >-0.00</td>
#       <td id="T_18649_row5_col5" class="data row5 col5" >-0.19</td>
#     </tr>
#   </tbody>
# </table>

# %%
evaluations = bench.evaluate_explanations(explanations, target=2)
bench.show_evaluation_table(evaluations)
# Out:
# Explanation eval:   0%|          | 0/6 [00:00<?, ?it/s]
# <style type="text/css">
# #T_d0ba4_row0_col0 {
#   background-color: #d5dfe7;
#   color: #000000;
#   background-color: #c38bc3;
#   color: #f1f1f1;
# }
# #T_d0ba4_row0_col1, #T_d0ba4_row5_col1 {
#   background-color: #f1f1f2;
#   color: #000000;
#   background-color: #b977b9;
#   color: #f1f1f1;
# }
# #T_d0ba4_row0_col2, #T_d0ba4_row5_col2 {
#   background-color: #87abc6;
#   color: #f1f1f1;
#   background-color: #dcc0dc;
#   color: #000000;
# }
# #T_d0ba4_row1_col0, #T_d0ba4_row2_col0 {
#   background-color: #dee5eb;
#   color: #000000;
#   background-color: #bf85bf;
#   color: #f1f1f1;
# }
# #T_d0ba4_row1_col1 {
#   background-color: #edeff1;
#   color: #000000;
#   background-color: #b876b8;
#   color: #f1f1f1;
# }
# #T_d0ba4_row1_col2 {
#   background-color: #cedae4;
#   color: #000000;
#   background-color: #c590c5;
#   color: #f1f1f1;
# }
# #T_d0ba4_row2_col1 {
#   background-color: #eff0f2;
#   color: #000000;
#   background-color: #b976b9;
#   color: #f1f1f1;
# }
# #T_d0ba4_row2_col2 {
#   background-color: #b7cbda;
#   color: #000000;
#   background-color: #cda0cd;
#   color: #000000;
# }
# #T_d0ba4_row3_col0 {
#   background-color: #eff0f2;
#   color: #000000;
#   background-color: #ba79ba;
#   color: #f1f1f1;
# }
# #T_d0ba4_row3_col1 {
#   background-color: #e4e9ed;
#   color: #000000;
#   background-color: #b56fb5;
#   color: #f1f1f1;
# }
# #T_d0ba4_row3_col2 {
#   background-color: #eab5b9;
#   color: #000000;
#   background-color: #a650a6;
#   color: #f1f1f1;
# }
# #T_d0ba4_row4_col0 {
#   background-color: #f2f1f1;
#   color: #000000;
#   background-color: #b977b9;
#   color: #f1f1f1;
# }
# #T_d0ba4_row4_col1 {
#   background-color: #d8e1e8;
#   color: #000000;
#   background-color: #b166b1;
#   color: #f1f1f1;
# }
# #T_d0ba4_row4_col2 {
#   background-color: #e06b74;
#   color: #f1f1f1;
#   background-color: #8f208f;
#   color: #f1f1f1;
# }
# #T_d0ba4_row5_col0 {
#   background-color: #d9e2e9;
#   color: #000000;
#   background-color: #c188c1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d0ba4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d0ba4_level0_col0" class="col_heading level0 col0" >aopc_compr</th>
#       <th id="T_d0ba4_level0_col1" class="col_heading level0 col1" >aopc_suff</th>
#       <th id="T_d0ba4_level0_col2" class="col_heading level0 col2" >taucorr_loo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0ba4_level0_row0" class="row_heading level0 row0" >Partition SHAP</th>
#       <td id="T_d0ba4_row0_col0" class="data row0 col0" >-0.16</td>
#       <td id="T_d0ba4_row0_col1" class="data row0 col1" >-0.00</td>
#       <td id="T_d0ba4_row0_col2" class="data row0 col2" >-0.60</td>
#     </tr>
#     <tr>
#       <th id="T_d0ba4_level0_row1" class="row_heading level0 row1" >LIME</th>
#       <td id="T_d0ba4_row1_col0" class="data row1 col0" >-0.10</td>
#       <td id="T_d0ba4_row1_col1" class="data row1 col1" >-0.02</td>
#       <td id="T_d0ba4_row1_col2" class="data row1 col2" >-0.20</td>
#     </tr>
#     <tr>
#       <th id="T_d0ba4_level0_row2" class="row_heading level0 row2" >Gradient</th>
#       <td id="T_d0ba4_row2_col0" class="data row2 col0" >-0.11</td>
#       <td id="T_d0ba4_row2_col1" class="data row2 col1" >-0.01</td>
#       <td id="T_d0ba4_row2_col2" class="data row2 col2" >-0.33</td>
#     </tr>
#     <tr>
#       <th id="T_d0ba4_level0_row3" class="row_heading level0 row3" >Gradient (x Input)</th>
#       <td id="T_d0ba4_row3_col0" class="data row3 col0" >-0.01</td>
#       <td id="T_d0ba4_row3_col1" class="data row3 col1" >-0.07</td>
#       <td id="T_d0ba4_row3_col2" class="data row3 col2" >0.33</td>
#     </tr>
#     <tr>
#       <th id="T_d0ba4_level0_row4" class="row_heading level0 row4" >Integrated Gradient</th>
#       <td id="T_d0ba4_row4_col0" class="data row4 col0" >0.00</td>
#       <td id="T_d0ba4_row4_col1" class="data row4 col1" >-0.14</td>
#       <td id="T_d0ba4_row4_col2" class="data row4 col2" >0.73</td>
#     </tr>
#     <tr>
#       <th id="T_d0ba4_level0_row5" class="row_heading level0 row5" >Integrated Gradient (x Input)</th>
#       <td id="T_d0ba4_row5_col0" class="data row5 col0" >-0.14</td>
#       <td id="T_d0ba4_row5_col1" class="data row5 col1" >-0.00</td>
#       <td id="T_d0ba4_row5_col2" class="data row5 col2" >-0.60</td>
#     </tr>
#   </tbody>
# </table>
